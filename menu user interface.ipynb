# %%
import os
import getpass
import pyttsx3
import speech_recognition as sr
import socket
import pyaudio

engine =  pyttsx3.init()


mic = sr.Microphone()
rec = sr.Recognizer()


s = socket.socket()
s.connect(("192.168.43.186",2222))



engine.say("Welcome to Tools Utility")
engine.runAndWait()
print("Welcome to Tools Utility")

engine.say("Enter your password")
engine.runAndWait()
pw = getpass.getpass("ENTER YOUR PASSWORD : ")

password = "redhat"






if pw == password:

    engine.say("Where would you like to start the program Locally or Remotely")
    engine.runAndWait()
    print("Where would you like to start the program Locally or Remotely")
    with mic as source:
        print ("\nplease select your choice : \n")
        audio = rec.listen(source)
        text = rec.recognize_google(audio)
        print(audio)

    if ("local" in text or "locally" in text):
        system = "local"
    if ("remote" in text or "remotly" in text):
        system = "remote"
    
    
    while True:

        if system == "local":


            os.system("clear")
            
            engine.say("Enter one of the following options")
            engine.runAndWait()


            print ("""
            answer to click a photo
            answer to start video camera
            answer to start mobile cameras
            answer to setup pre-requsite to set-up hadoop cluster(JAVA AND HADOOP)
            answer to setup master node
            answer to setup slave node
            answer to setup job tracker
            answer to setup task tracker
            answer to setup client
            answer to exit
            """)

            with mic as source:
                print ("\nplease select your choice : \n")
                audio = rec.listen(source)
                text = rec.recognize_google(audio)
                print(audio)

                
            if ("photo" in text and "click" in text):
                print("capturing picture ......")
                ch = 1
                s.send(ch.encode())
                print("picture clicked...")
                input("Press Enter to Continue .....")

            if ("live" in text and "camera" in text):
                print("starting live camera .....")
                ch = 2
                s.send(ch.encode())
                print("Stream Ended .....")
                input("Press Enter to Continue .....")

            if ("mobile" in text and "camera" in text):
                print("starting mobile live camera .....")
                ch = 3
                s.send(ch.encode())
                print("Stream Ended .....")
                input("Press Enter to Continue .....")

            if ("setup" in text and "hadoop" in text):
                ch = 4
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("master" in text and "setup" in text):
                ch = 5
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("datanode" in text and "setup" in text):
                ch = 6
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("job" in text and "setup" in text):
                ch = 7
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("task" in text and "setup" in text):
                ch = 8
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("client" in text and "setup" in text):
                ch = 9
                s.send(ch.encode())
                input("Press Enter to Continue .....")

                
                
                
                
                
                
                

            if ("exit" in text and "close" in text):
                print("\nThank You")
                engine.say("Thank You for using our tool ... see you soon")
                engine.runAndWait()
                os.system('tput setaf 0')
                exit()
            


        elif system == "remote":

            
            os.system("clear")
            
            engine.say("Enter one of the following options")
            engine.runAndWait()
            
            print ("""
            answer to remote access device and click a picture
            answer to setup pre-requsite to set-up hadoop cluster(JAVA AND HADOOP)
            answer to setup master node
            answer to setup slave node
            answer to setup job tracker
            answer to setup task tracker
            answer to setup client
            answer to exit
            """)

            with mic as source:
                print ("\nplease select your choice : \n")
                audio = rec.listen(source)
                text = rec.recognize_google(audio)
                print(audio)

                
                
                
            if ("click" in text and "photo" in text):

                ch = 10
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                print("Sending program file to remote device . . . . .")
                print("Executing file on remote device . . . . .")
                print("Obtaining Result from remote device . . . . .")
                input("Press Enter to Continue .....")

                
            if ("setup" in text and "hadoop" in text):

                ch = 11
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")




            if ("setup" in text and "master" in text):

                ch = 12
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("data" in text and "setup" in text):

                ch = 13
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("job" in text and "setup" in text):

                ch = 14
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("task" in text and "setup" in text):

                ch = 15
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("client" in text and "setup" in text):

                ch = 16
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")


            if ("exit" in text and "close" in text):
                print("\nThank You")
                engine.say("Thank You for using our tool ... see you soon")
                engine.runAndWait()
                os.system('tput setaf 0')
                exit()
                
else:
    
    print("Login Error ... Exiting")
    engine.say("Login Error ..... Exiting Program")
    engine.runAndWait()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-2-ce754e44cfed> in <module>
#      14
#      15 s = socket.socket()
# ---> 16 s.connect(("192.168.43.186",2222))
#      17
#      18
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
engine.say("Welcome to Tools Utility")
engine.runAndWait()
print("Welcome to Tools Utility")

engine.say("Enter your password")
engine.runAndWait()
pw = getpass.getpass("ENTER YOUR PASSWORD : ")

password = "gajendra"

# %%
if pw == password:

    engine.say("Where would you like to start the program Locally or Remotely")
    engine.runAndWait()
    print("Where would you like to start the program Locally or Remotely")
    with mic as source:
        print ("\nplease select your choice : \n")
        audio = rec.listen(source)
        text = rec.recognize_google(audio)
        print(audio)

    if ("local" in text or "locally" in text):
        system = "local"
    if ("remote" in text or "remotly" in text):
        system = "remote"
    
    
    while True:

        if system == "local":


            os.system("clear")
            
            engine.say("Enter one of the following options")
            engine.runAndWait()


            print ("""
            answer to click a photo
            answer to start video camera
            answer to start mobile cameras
            answer to setup pre-requsite to set-up hadoop cluster(JAVA AND HADOOP)
            answer to setup master node
            answer to setup slave node
            answer to setup job tracker
            answer to setup task tracker
            answer to setup client
            answer to exit
            """)

            with mic as source:
                print ("\nplease select your choice : \n")
                audio = rec.listen(source)
                text = rec.recognize_google(audio)
                print(audio)

                
            if ("photo" in text and "click" in text):
                print("capturing picture ......")
                ch = 1
                s.send(ch.encode())
                print("picture clicked...")
                input("Press Enter to Continue .....")

            if ("live" in text and "camera" in text):
                print("starting live camera .....")
                ch = 2
                s.send(ch.encode())
                print("Stream Ended .....")
                input("Press Enter to Continue .....")

            if ("mobile" in text and "camera" in text):
                print("starting mobile live camera .....")
                ch = 3
                s.send(ch.encode())
                print("Stream Ended .....")
                input("Press Enter to Continue .....")

            if ("setup" in text and "hadoop" in text):
                ch = 4
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("master" in text and "setup" in text):
                ch = 5
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("datanode" in text and "setup" in text):
                ch = 6
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("job" in text and "setup" in text):
                ch = 7
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("task" in text and "setup" in text):
                ch = 8
                s.send(ch.encode())
                input("Press Enter to Continue .....")

            if ("client" in text and "setup" in text):
                ch = 9
                s.send(ch.encode())
                input("Press Enter to Continue .....")


            if ("exit" in text and "close" in text):
                print("\nThank You")
                engine.say("Thank You for using our tool ... see you soon")
                engine.runAndWait()
                os.system('tput setaf 0')
                exit()
            


        elif system == "remote":

            
            os.system("clear")
            
            engine.say("Enter one of the following options")
            engine.runAndWait()
            
            print ("""
            answer to remote access device and click a picture
            answer to setup pre-requsite to set-up hadoop cluster(JAVA AND HADOOP)
            answer to setup master node
            answer to setup slave node
            answer to setup job tracker
            answer to setup task tracker
            answer to setup client
            answer to exit
            """)

            with mic as source:
                print ("\nplease select your choice : \n")
                audio = rec.listen(source)
                text = rec.recognize_google(audio)
                print(audio)

                
                
                
            if ("click" in text and "photo" in text):

                ch = 10
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                print("Sending program file to remote device . . . . .")
                print("Executing file on remote device . . . . .")
                print("Obtaining Result from remote device . . . . .")
                input("Press Enter to Continue .....")

                
            if ("setup" in text and "hadoop" in text):

                ch = 11
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")




            if ("setup" in text and "master" in text):

                ch = 12
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("data" in text and "setup" in text):

                ch = 13
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("job" in text and "setup" in text):

                ch = 14
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("task" in text and "setup" in text):

                ch = 15
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")

            if ("client" in text and "setup" in text):

                ch = 16
                s.send(ch.encode())
                ip = input("Enter the IP to access : ")
                s.send(ip.encode())
                input("Press Enter to Continue .....")


            if ("exit" in text and "close" in text):
                print("\nThank You")
                engine.say("Thank You for using our tool ... see you soon")
                engine.runAndWait()
                os.system('tput setaf 0')
                exit()
                
else:
    
    print("Login Error ... Exiting")
    engine.say("Login Error ..... Exiting Program")
    engine.runAndWait()
